# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy import interpolate
datos = np.loadtxt('data_mean_sq.txt')
b=np.zeros((50,1))
aux=np.ones((50,1))
A=np.zeros((50,2))
A[:,0]=datos[:,0]
A[:,1]=aux[:,0]
b[:,0]=datos[:,1]
iz=np.matmul(A.T,A)
dere=np.matmul(A.T,b)
res=np.linalg.solve(iz,dere)
print (res)
x=np.linspace(0,35)
y=2.04894953*x+26.51298318
plt.scatter(datos[:,0],datos[:,1])
plt.plot(x,y,'r')
plt.show()
print("el valor de m es",res[0],"el valor de el punto de corte es",res[1])
print("la prubes esta en que si se usa el comando linreg da ", np.polyfit(datos[:,0], datos[:,1], 1))

#punto b
print("")
print("la parte b es:")
datosx= 6*np.random.rand(30)
datosx1= 6*np.random.rand(30)
datosx2= 6*np.random.rand(30)
datosx3= 6*np.random.rand(30)
datosx4= 6*np.random.rand(30)
datosx5= 6*np.random.rand(30)
datosx6= 6*np.random.rand(30)
datosx7= 6*np.random.rand(30)
datosx8= 6*np.random.rand(30)
datosx9= 6*np.random.rand(30)

variacion0= np.random.normal(0.0,0.2,30)
variacion1= np.random.normal(0.0,0.2,30)
variacion2= np.random.normal(0.0,0.2,30)
variacion3= np.random.normal(0.0,0.2,30)
variacion4= np.random.normal(0.0,0.2,30)
variacion5= np.random.normal(0.0,0.2,30)
variacion6= np.random.normal(0.0,0.2,30)
variacion7= np.random.normal(0.0,0.2,30)
variacion8= np.random.normal(0.0,0.2,30)
variacion9= np.random.normal(0.0,0.2,30)




datosy1 = 10*np.exp(-datosx/0.5) + variacion0
datosy2 = 10*np.exp(-datosx1/0.5) + variacion1
datosy3 = 10*np.exp(-datosx2/0.5) + variacion2
datosy4 = 10*np.exp(-datosx3/0.5) + variacion3
datosy5 = 10*np.exp(-datosx4/0.5) + variacion4
datosy6 = 10*np.exp(-datosx5/0.5) + variacion5
datosy7 = 10*np.exp(-datosx6/0.5) + variacion6
datosy8 = 10*np.exp(-datosx7/0.5) + variacion7
datosy9 = 10*np.exp(-datosx8/0.5) + variacion8
datosy10 = 10*np.exp(-datosx9/0.5) + variacion9

Y1=np.log(np.asarray(datosy1)+1)
Y2=np.log(np.asarray(datosy2)+1)
Y3=np.log(np.asarray(datosy3)+1)
Y4=np.log(np.asarray(datosy4)+1)
Y5=np.log(np.asarray(datosy5)+1)
Y6=np.log(np.asarray(datosy6)+1)
Y7=np.log(np.asarray(datosy7)+1)
Y8=np.log(np.asarray(datosy8)+1)
Y9=np.log(np.asarray(datosy9)+1)
Y10=np.log(np.asarray(datosy10)+1)
p1 =np.polyfit(datosx, Y1, 1)
p2= np.polyfit(datosx1, Y2, 1)
p3= np.polyfit(datosx2, Y3, 1)
p4= np.polyfit(datosx3, Y4, 1)
p5= np.polyfit(datosx4, Y5, 1)
p6= np.polyfit(datosx5, Y6, 1)
p7= np.polyfit(datosx6, Y7, 1)
p8= np.polyfit(datosx7, Y8, 1)
p9= np.polyfit(datosx8, Y9, 1)
p10= np.polyfit(datosx9, Y10, 1)

print("la primera recta es",p1)
print("la segunda recta es",p2)
print("la tercera recta es",p3)
print("la cuarta recta es",p4)
print("la quinta recta es",p5)
print("la sexta recta es",p6)
print("la septima recta es",p7)
print("la octava recta es",p8)
print("la novena recta es",p9)
print("la decima recta es",p10)
YF1=p1[1]+datosx*p1[0]
YF2=p2[1]+datosx1*p2[0]
YF3=p3[1]+datosx2*p3[0]
YF4=p4[1]+datosx3*p4[0]
YF5=p5[1]+datosx4*p5[0]
YF6=p6[1]+datosx5*p6[0]
YF7=p7[1]+datosx6*p7[0]
YF8=p8[1]+datosx7*p8[0]
YF9=p9[1]+datosx8*p9[0]
YF10=p10[1]+datosx9*p10[0]



plt.scatter(datosx,datosy1)
plt.scatter(datosx1,datosy2)
plt.scatter(datosx2,datosy3)
plt.scatter(datosx3,datosy4)
plt.scatter(datosx4,datosy5)
plt.scatter(datosx5,datosy6)
plt.scatter(datosx6,datosy7)
plt.scatter(datosx7,datosy8)
plt.scatter(datosx8,datosy9)
plt.scatter(datosx9,datosy10)
plt.show()
plt.scatter(datosx,YF1)
plt.scatter(datosx1,YF2)
plt.scatter(datosx2,YF3)
plt.scatter(datosx3,YF4)
plt.scatter(datosx4,YF5)
plt.scatter(datosx5,YF6)
plt.scatter(datosx6,YF7)
plt.scatter(datosx7,YF8)
plt.scatter(datosx8,YF9)
plt.scatter(datosx9,YF10)
plt.show()

varA=[p1[1],p2[1],p3[1],p4[1],p5[1],p6[1],p7[1],p8[1],p9[1],p10[1]]
varT=[p1[0],p2[0],p3[0],p4[0],p5[0],p6[0],p7[0],p8[0],p9[0],p10[0]]

  
print("la varianza de A es ",np.var(varA))
print("la varianza de tao es",np.var(varT))
# Out:
# [[  2.04894953]
#  [ 26.51298318]]
# el valor de m es [ 2.04894953] el valor de el punto de corte es [ 26.51298318]
# la prubes esta en que si se usa el comando linreg da  [  2.04894953  26.51298318]
#
# la parte b es:
# la primera recta es [-0.32049933  1.35382201]
# la segunda recta es [-0.1462393   0.63248122]
# la tercera recta es [-0.24235255  0.95170802]
# la cuarta recta es [-0.34637913  1.28310243]
# la quinta recta es [-0.26431513  1.17670556]
# la sexta recta es [-0.2147051   0.86051797]
# la septima recta es [-0.285582    1.12446099]
# la octava recta es [-0.29998692  1.22915727]
# la novena recta es [-0.26703308  1.26169815]
# la decima recta es [-0.31613233  1.45920552]
# la varianza de A es  0.0563127146073
# la varianza de tao es 0.00308328573202

# %%
min(abs(np.asarray(datosy1)))
# Out:
# 0.015856687623381844

# %%
plt.plot(np.log(datosy1))
plt.show()
# Out:
# /Users/mariafernandagomez/miniconda3/lib/python3.4/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(datosx,datosy1)

# %%
xT = 6*np.random.rand(30)
yT = 10*np.exp(-xT/0.5) + np.random.normal(0.0,2.5)

# %%
plt.plot(xT,(yT),'ko')
yT
# Out:
# array([-3.60746325, -3.60803277, -3.55858761, -3.60780375, -3.60793827,
#        -3.609272  , -3.4783902 , -3.49284022, -3.60914042, -3.60890427,
#        -3.55229897, -3.58379786,  1.72433642, -3.60778522, -3.60918094,
#        -3.29773605, -3.54944724, -3.58853242, -3.60385936, -1.46260923,
#        -3.54918064, -3.60871413, -3.60713415, -3.60929762, -3.51559459,
#        -3.58698774, -1.73254468, -3.56847647, -2.45677488, -3.46749756])
